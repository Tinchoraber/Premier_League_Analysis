# %%
import pandas as pd
import numpy as np

print("Librerías cargadas correctamente ✓")
# Out:
# Librerías cargadas correctamente ✓

# %%
df = pd.read_csv(r"C:\Users\mrabe\OneDrive\Documentos\Premier League Analysis\Data\premier-league-matches.csv")
print(f"Dataset cargado: {df.shape[0]} filas y {df.shape[1]} columnas")
# Out:
# Dataset cargado: 12026 filas y 8 columnas

# %%
df.head()
# Out:
#    Season_End_Year  Wk        Date            Home  HomeGoals  AwayGoals  \
# 0             1993   1  1992-08-15   Coventry City          2          1
# 1             1993   1  1992-08-15    Leeds United          2          1
# 2             1993   1  1992-08-15   Sheffield Utd          2          1
# 3             1993   1  1992-08-15  Crystal Palace          3          3
# 4             1993   1  1992-08-15         Arsenal          2          4
#
#              Away FTR
# 0   Middlesbrough   H
# 1       Wimbledon   H
# 2  Manchester Utd   H
# 3       Blackburn   D
# 4    Norwich City   A

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12026 entries, 0 to 12025
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Season_End_Year  12026 non-null  int64
#  1   Wk               12026 non-null  int64
#  2   Date             12026 non-null  object
#  3   Home             12026 non-null  object
#  4   HomeGoals        12026 non-null  int64
#  5   AwayGoals        12026 non-null  int64
#  6   Away             12026 non-null  object
#  7   FTR              12026 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 751.8+ KB

# %%
df.describe()
# Out:
#        Season_End_Year            Wk     HomeGoals     AwayGoals
# count     12026.000000  12026.000000  12026.000000  12026.000000
# mean       2007.713620     19.730501      1.524364      1.142525
# std           9.072559     11.123916      1.306417      1.133930
# min        1993.000000      1.000000      0.000000      0.000000
# 25%        2000.000000     10.000000      1.000000      0.000000
# 50%        2008.000000     20.000000      1.000000      1.000000
# 75%        2016.000000     29.000000      2.000000      2.000000
# max        2023.000000     42.000000      9.000000      9.000000

# %%
nulos = df.isnull().sum()
print("Valores nulos por columna:")
print(nulos[nulos > 0])
# Out:
# Valores nulos por columna:
# Series([], dtype: int64)

# %%
duplicados = df.duplicated().sum()
print(f"Filas duplicadas: {duplicados}")
# Out:
# Filas duplicadas: 0

# %%
print(df.columns.tolist())
# Out:
# ['Season_End_Year', 'Wk', 'Date', 'Home', 'HomeGoals', 'AwayGoals', 'Away', 'FTR']

# %%
print(df.dtypes)
# Out:
# Season_End_Year     int64
# Wk                  int64
# Date               object
# Home               object
# HomeGoals           int64
# AwayGoals           int64
# Away               object
# FTR                object
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

print("Valores únicos en FTR:", df['FTR'].unique())

print("Temporadas:", sorted(df['Season_End_Year'].unique()))
# Out:
# Valores únicos en FTR: ['H' 'D' 'A']
# Temporadas: [np.int64(1993), np.int64(1994), np.int64(1995), np.int64(1996), np.int64(1997), np.int64(1998), np.int64(1999), np.int64(2000), np.int64(2001), np.int64(2002), np.int64(2003), np.int64(2004), np.int64(2005), np.int64(2006), np.int64(2007), np.int64(2008), np.int64(2009), np.int64(2010), np.int64(2011), np.int64(2012), np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023)]

# %%
df['TotalGoals'] = df['HomeGoals'] + df['AwayGoals']

print("Columna TotalGoals creada ✓")
df.head()
# Out:
# Columna TotalGoals creada ✓
#    Season_End_Year  Wk       Date            Home  HomeGoals  AwayGoals  \
# 0             1993   1 1992-08-15   Coventry City          2          1
# 1             1993   1 1992-08-15    Leeds United          2          1
# 2             1993   1 1992-08-15   Sheffield Utd          2          1
# 3             1993   1 1992-08-15  Crystal Palace          3          3
# 4             1993   1 1992-08-15         Arsenal          2          4
#
#              Away FTR  TotalGoals
# 0   Middlesbrough   H           3
# 1       Wimbledon   H           3
# 2  Manchester Utd   H           3
# 3       Blackburn   D           6
# 4    Norwich City   A           6

# %%
df.to_csv(r"C:\Users\mrabe\OneDrive\Documentos\Premier League Analysis\Data\matches_limpio.csv", index=False)
print("Dataset limpio guardado ✓")
# Out:
# Dataset limpio guardado ✓
